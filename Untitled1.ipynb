# %%
from collections import defaultdict, Counter
from operator import itemgetter
import re,operator
import bz2, json
from collections import defaultdict
import math
WORD_LEN_COEFF = 1
THRESHOLD_COEFF = 0.5
DROP = 1.5
DROP_1 = 2
AFFIX_LEN = 1
THRESHOLD_OSTAT=0.5
N=5#шлейфовый порог

trie, voc, words, prob,word_count,average_word_len,bases, affixes, next_bases, false_affixes, removed_ost, specter\
    = None, None, None, None, None, None, None, None, None, None, None, None



def main():
    global trie, words, voc, prob, average_word_len,affix
    voc = load_voc()
    words = sorted(list(voc.keys()))
    word_count = sum([voc[k] for k in voc])
    average_word_len = sum([len(w)*voc[w] for w in words]) / word_count
    len_search = int(average_word_len * WORD_LEN_COEFF) #это максимальная разрешенная длина аффикса
    print("{} словоформ, {} словоупотреблений, средняя длина слова {} ".format(len(words), word_count, average_word_len))

    # подсчет безусловных вероятностей букв
    # trie, prob = build_trie_and_prob(voc)
    prob = json.load(open("prob.json", encoding="utf-8"))
    strie = bz2.BZ2File('trie.json.bz2', 'r').read().decode(encoding='utf-8')
    trie = json.loads(strie)
    del strie
    print("Безусловные вероятности первых 10 букв:\n========================\n", 
        sorted([(letter,nv) for letter,nv in prob.items()], key=itemgetter(1), reverse=True)[:10])

    # подсчет условных вероятностей букв
    cond_prob = build_cond_prob(voc, prob, len_search)

    # информанты - это буквы с макс значением КФ в каждой позиции
    informants = find_informants(prob, cond_prob, len_search)
    print("ИНФОРМАНТЫ:\n===================")
    print(informants)

    # отправной аффикс начинаем строить с информанта имеющего max КФ
    affix=informants[0]
    affix=extend_right(*affix)
    affix=extend_left(affix, trie, len_search)
    print("ОТПРАВНОЙ АФФИКС:\n===================")    
    print(affix)


def load_voc():
    # Загрузить словарь количеств из файла.
    # Словарь содержит частоты слов в виде {слово: число вхождений в корпус, ... },
    # например {"көппөҕү" : 4, "хазар" : 3, ...}
    #
    # корпус в формате txt  занимет 174 МБ, словарь частот в json 10,4МБ,
    # после сжатия в формат .bz2 1,7 МБ
    svoc = bz2.BZ2File('voc.json.bz2', 'r').read().decode(encoding='utf-8')
    voc = json.loads(svoc)
    del svoc
    return voc


def build_trie_and_prob(voc):
    #подсчитываем частоты букв и строим дерево оконочаний
    prob = defaultdict(lambda: 0)
    trie = {'n':0}
    for w,n in voc.items(): #для каждого слова в списке
        word = w[::-1]  # переворачиваем слово, читаем слово с конца
        current_dict = trie
        trie['n'] += n
        for letter in word:  # для буквы в слове
            prob[letter]+=n
            current_dict = current_dict.setdefault(letter, {'n': 0}) #получить значение из словаря по ключу.
                                                                     #Автоматически добавляет элемент словаря, если он отсутствует.
            current_dict['n']+=n
        current_dict['#'] = n

    total = sum([n for n in prob.values()])#84263863
    for k,v in prob.items():
        prob[k] = v/total

    return trie, prob


def build_cond_prob(voc, prob, len_search):
    letters = list(prob.keys())

    cond_prob = defaultdict(lambda: 0) #словарь для условных вероятностей
    total = defaultdict(lambda: 0)

    for word,n in voc.items():#для слова в словаре
        positions = range(-min(len_search, len(word) - 2), 0) # from -7 to 0
        for i in positions:
            cond_prob[(i, word[i])] += n
            total[i] += n # dictionary with prob of char words?

    for posChar in cond_prob: #получаем из частот вероятности
        i = posChar[0]
        cond_prob[posChar] /= total[i]

    return cond_prob


def find_informants(prob, cond_prob, len_search):
    max_cond = defaultdict(lambda: 0.0)
    maxlet = ['']*8
    #для каждой позиции ищем букву с наибольшим значением условной вероятности,
    for posChar in cond_prob:#цикл по позициям букв в условной вероятности
        aff_len = posChar[0]
        if cond_prob[posChar] > max_cond[aff_len]:
            max_cond[aff_len] = cond_prob[posChar]
            maxlet[-aff_len] = posChar[1]

    print("Наиболее частые буквы по позициям:\n============================\n", maxlet[-1:0:-1],"\n")

    print("Максимальные вероятности по позициям:\n============================\n", max_cond,"\n")
    #порог медиального разбиения - половина условной вероятности , буквы с УВ не меньше порога - верхнее подмножеств
    cond_prob_sup = {}
    for posChar in cond_prob:
            i = posChar[0]
            if cond_prob[posChar] > THRESHOLD_COEFF * max_cond[i]:
                cond_prob_sup[posChar] = cond_prob[posChar]

    # КФ = условная вер по данной позиции / безусл вероятность
    cf = {}
    for posChar in cond_prob_sup:
        char = posChar[1]
        cf[posChar] = cond_prob_sup[posChar] / prob[char]

    print("КФ для верхних подмножества:\n====================\n");
    for aff_len in set(map(itemgetter(0), cf.keys())):
        print(aff_len, "**")
        for k,v in cf.items():
            if k[0] == aff_len:
                print(k[1], "{:.4f}".format(v), end="  ")
        print("")

    # информанты - это буквы с макс значением КФ в каждой позиции
    informants = []
    for aff_len in range(-len_search, 0):
        kmax = max({k for k in cf if k[0] == aff_len}, key=lambda k: cf[k])
        informants.append((kmax[1], aff_len, cf[kmax]))

    informants.sort(key = itemgetter(2), reverse=True)
    return informants


def extend_right(char, pos, cf):
    if pos == -1:#если информант в последней позиции, то расширять некуда
        return char #возвращаем информант как аффикс
    d = defaultdict(int)
    for w,n in voc.items():#для буквы и частоты в словаре
        if w[pos:pos+1]==char: #если буква в позиции равна нашей, то посчитаем это окончание
            d[w[pos+1:]]+=n
    return char+max(d.keys(), key=lambda end: d[end]) #прибавляем к информанту самое частое окончание


def extend_left(affix, trie, len_search):
    #расширяем аффикс влево используя trie

    current_dict = trie
    for ch in affix[::-1]:
        current_dict = current_dict[ch]

    aff_len = len(affix)

    """ 
    Для поиска буквы слева:
        идем по дереву trie
        по две самые частотные буквы делим друг на друга, при мере перепада большей 1.5 прибавляем к информанту более частую из них.
       Иначе начинаем рассматривать по две самые частотные буквы/на следующие две, 
    если мера перепада в одной из них больше двух, то из данной пары берем более частотную и прибавляем ее к аффиксу. 
    """
    #пока позиция символа в слове больше разрешенной длины аффикса
    while aff_len < len_search:
        #составляем список всех букв предшествующих аффиксу с количествами
        L = [(l, current_dict[l]["n"]) for l in current_dict.keys() if l not in '#n']
        #сортируем по количествам
        L.sort(key = itemgetter(1), reverse = True)
        #if affix=='нан':
            #import pdb
            #pdb.set_trace()
        ch = L[0][0]
        if L[0][1] > DROP*L[1][1]:
            affix = ch + affix
            current_dict = current_dict[ch]
        else:
            if (L[0][1]+L[1][1]) / (L[2][1]+L[3][1]) > 2:
                affix = ch + affix
                current_dict = current_dict[ch]
            else:
                break
        aff_len+=1

    return affix

# %%
main()
# Out:
# 386233 словоформ, 11859267 словоупотреблений, средняя длина слова 7.1053179762290535
# Безусловные вероятности первых 10 букв:
# ========================
#  [('а', 0.13174638100795355), ('т', 0.07463523242460413), ('н', 0.07183703410321932), ('р', 0.06989005476760542), ('э', 0.06769593508904286), ('и', 0.06497202721408583), ('ы', 0.05657750345483212), ('л', 0.052736912856701096), ('у', 0.048080219156342266), ('о', 0.04801633649290444)]
# Наиболее частые буквы по позициям:
# ============================
#  ['а', 'а', 'т', 'а', 'т', 'а', 'н']
#
# Максимальные вероятности по позициям:
# ============================
#  defaultdict(<function find_informants.<locals>.<lambda> at 0x0000024CD62DCA60>, {-6: 0.13725284548556266, -5: 0.10984460793132571, -4: 0.13300193926114215, -3: 0.11746170593037474, -2: 0.21185955687204952, -1: 0.22671356984582827, -7: 0.10984867258690777})
#
# КФ для верхних подмножества:
# ====================
#
# -1 **
# н 3.1559  р 2.0092  а 1.1595
# -7 **
# ы 0.9773  р 1.1054  а 0.8338  л 1.7512  т 1.0604  и 0.9824
# -6 **
# р 0.9975  а 1.0418  т 0.9701  э 1.0297  л 1.6040
# -5 **
# а 0.7812  н 0.8144  т 1.4718  и 0.8949  р 1.1912  л 1.9490
# -4 **
# а 1.0095  ы 1.4735  т 1.2438  и 1.2629  э 1.0359  л 1.7136
# -3 **
# н 1.4117  л 1.3875  т 1.5738  а 0.8120  р 1.3286
# -2 **
# а 1.6081  э 1.7332
# ИНФОРМАНТЫ:
# ===================
# [('н', -1, 3.15594279017803), ('л', -5, 1.94903926924671), ('л', -7, 1.751239386475054), ('э', -2, 1.7331937693949762), ('л', -4, 1.7135874901772652), ('л', -6, 1.604008680102341), ('т', -3, 1.573810412515745)]
# ОТПРАВНОЙ АФФИКС:
# ===================
# ыытынан

# %%
affix
# Out:
# 'ыытынан'

# %%
# узел trie, соответствующийокончанию aff
def affix_node(aff):
    global trie
    current_node = trie
    for char in aff[::-1]:
        current_node = current_node[char]
    return current_node

# рекурсивно возвращает все основы, растущие из данного узла
def word_dfs(node, ending=''):
    result = [ending] if '#' in node else []
    for ch in node:
        if ch in ['#', 'n']: continue
        result += word_dfs(node[ch], ch+ending)
    return result
  
# все основы, растущие из данного узла 
def bases_with_affix(aff):
    return sorted([b for b in word_dfs(affix_node(aff)) if len(b)>1])

from bisect import bisect_left
# суммарная встречаемость основы b с любыми остатками
def build_freq_bases(b):
    freq = 0
    for w in words[bisect_left(words, b):]:
                if not w.startswith(b) : break   
                freq += voc[w]
    return freq   


def build_ost(bases):
    global words, voc
    ostat = defaultdict(int)
    for b in bases:
        affix_pos = len(b)
        for w in words[bisect_left(words, b):]:
            if not w.startswith(b): break 
            if not w[affix_pos:] in affix:
                ostat[w[affix_pos:]] += voc[w]  # вариант с подсчетом словоупотреблений
                # ostat[w[affix_pos:]] += 1  # вариант с подсчетом словоформ    
    return ostat

#affixes - нормальные


def fast_alg(bases, specter, freq_bases,step, del_aff):
    max_ost_val=max(specter.values())
    #те пары к в у которых к больше макс
    inf_zveno={ost: v for ost,v in specter.items() if v > max_ost_val / 2}
    print("Zveno: ", inf_zveno)
    #дольше нужна сочетаемость с некоторой группой контрольных основ
    #верхнее подмножество баз очередного вида    
    next_base_freq={}
    max_nb_freq=0
    
    freq_cur_bases = {b: sum([voc.get(b+ost,0) for ost in specter]) for b in bases}
    max_freq_cur = max(freq_cur_bases.values())
    print("Max freq: ",max_freq_cur)
    #верхнее подмножество баз очередного вида
    control_bases=[b for b,freq in freq_cur_bases.items() if freq >= max_freq_cur/2 ]
    if len(control_bases)==1:
        lower=[(b, freq)for b,freq in freq_cur_bases.items()if freq<max_freq_cur]
        control_bases.append(max(lower, key=itemgetter(1))[0])
    print("Control bases", control_bases)
    
    #Первый критерий принадлежности к парадигме - сочетаемость остатков в звене с основами control_bases
    keep_ost = [ost for ost in inf_zveno if all([b+ost in voc for b in control_bases])]
    removed_ost = [ost for ost in inf_zveno if ost not in keep_ost]  
    
    print("Keep:", keep_ost)
    next_bases = [b for b in bases if all([b+aff in voc for aff in keep_ost]) and
                                             freq_cur_bases[b]>step]
    if removed_ost:
        del_aff += destiny_of_affix(removed_ost, next_bases,voc)
        for x in del_aff:
            del specter[x]

    print("!!!!!!!!!!!Removed ost:", removed_ost)
    return keep_ost

def destiny_of_affix(removed_ost, next_bases, voc):
    #проверка на меру децентрации
    #если >=1/2 синтагматической вероятности падает на парадигматически малую(0,1) часть баз - то аффикс искл из парадигмы до конца рассм
    #иначе - аффикс выводится из звена, но сохраняется в спектре остатков
    removed_aff=[]
    for aff in removed_ost:
        freq_b=sorted([(base, voc.get(base+aff,0)) for base in next_bases], key = itemgetter(1), reverse = True)
        L = len(freq_b)//10
        S = sum(map(itemgetter(1),freq_b))
        if sum(map(itemgetter(1),freq_b[:L])) >= 1/2*S:
            removed_aff.append(aff)
    return removed_aff

    #проверка сочетаемости синтагматической аероятности аффикса с количеством оставшихся после групповой редукции баз, принимающих данный аффикс


def direct_alg(bases, specter, false_affixes):
    global prob, voc
    # верхнее подмножество остатков текущего вида
    m = max(specter.values()) * THRESHOLD_OSTAT
    upper_set = {ost: val for ost,val in specter.items() if val > m }
    if not [ost for ost in upper_set if ost not in false_affixes]:
        sp_list = sorted([(ost,val) for ost,val in specter.items()], key=itemgetter(1), reverse=True)
        for ost,val in sp_list:
            if ost not in false_affixes:
                break
        upper_set[ost] = val
    print("Верхнее подмножество остатков текущего вида,", len(upper_set), "шт.") 
    # ВЫЧИСЛИТЬ незав  для остатков из upper_set
    nv = {}
    summ_kol = 0

    for ost, kol in specter.items(): #ostat - defdict
        summ_kol += kol
        nezav_ver = 1
        for ch in ost:
            nezav_ver *= prob[ch]
        nv[ost]=nezav_ver

    # усл вероятности
    uv = {}
    for ost, kol in specter.items():
        uv[ost] = kol / summ_kol
    # КФ - отношение условной вероятности к безусловной
    corr_func={}
    for ost in upper_set:
        corr_func[ost]= uv[ost]/nv[ost]
    corr_func = [(ost, cf) for ost,cf in corr_func.items() if ost not in false_affixes]
    corr_func = sorted(corr_func, key = itemgetter(1), reverse= True)
    print("Коррелятивная функция: ", corr_func)
    if not corr_func:  # суперпороговые редукции исчерпали спектр остатков
        print("Остались только ложные остатки ")
        return []
    # найти след информант
    informant = corr_func[0][0]
    print("Информант: ", informant)
    return [informant]

def check_agglut_part():
    return 0


def build_class(bootstrap_affix):
    global words, average_word_len,THRESHOLD_OSTAT, thres_reduction, false_affixes, specter

    k = 10**(math.log(average_word_len, 10) / (1 + 0.02*math.log( len(voc), 10)) )
        # коэффициент редукции
    print("Поправочный коэффициент:", k)
    thres_reduction = 1 / average_word_len  #порог редукции
    print("Порог редукции:", thres_reduction)

    affixes = [bootstrap_affix]  # найденные аффиксы парадигмы
    false_affixes=[]  # список отвергнутых аффиксов, давших  ложный шаг

    bases = [bases_with_affix(bootstrap_affix)]
    specter = [build_ost(bases[0])]
    freq_bases = {b: build_freq_bases(b) for b in bases[0]}
    step = 1
    fast = False

    while True:
        print("\n***", step)
        print("Основы {}-го вида: {} шт.".format(step, len(bases[-1])))
        print("Аффиксы ",affixes)
        print("Спектр остатков {}-го вида: {} шт.".format(step, len(specter[-1])))

        if not specter[-1]:  # исчерпаны все остатки в спектре
            print("Исчерпаны все остатки в спектре")
            break         
        if not fast:
            print("Прямой ход: ")
            next_affixes = direct_alg(bases[-1], specter[-1], false_affixes)
            if not next_affixes:
                break
        else:
            print("Ускоренный ХОД!!!!!!!!")
            del_aff=[]
            next_affixes = fast_alg(bases[-1], specter[-1], freq_bases, step, del_aff)
            if not next_affixes:
                fast = False
                continue

        #основы следующего вида
        next_bases = [b for b in bases[-1] if all([b+aff in voc for aff in next_affixes]) and
                                             freq_bases[b]>step]
          
        # Поправочный коэффициент
        # увеличивается во столько раз сколько аффиксов было сохранено в звене
        K = k*len(next_affixes)

        # Мера редукции
        # доля основ текущего вида, не принимающих остатки следующего вида
        N = len(bases[-1])
        reduction = (N - len(next_bases)) / (K * N)
        print("Мера редукции: ", reduction)
        
        if reduction > thres_reduction: #суперпороговая редукция
            false_affixes+=next_affixes
            print("Суперпороговая редукция, ложные остатки", false_affixes)
            if len(false_affixes)>average_word_len:
                print("Cуперпороговая редукция повторяется большее число раз, чем средняя длина словоформы")
                break
            fast=False
        else:
            step += 1
            false_affixes = []
            affixes += next_affixes
            #спектр остатков следующего вида
            next_specter = {ost: sum([voc.get(b + ost, 0 ) for b in next_bases]) for ost in specter[-1]}
            next_specter = {ost:v for ost, v in next_specter.items() if v>0 and ost not in next_affixes}

            bases.append(next_bases)
            specter.append(next_specter)

            if (len(next_bases)<=2):
                print("Остались две базы очередного вида") 
                break
            if reduction < thres_reduction/2:#если редукция < порога редукции/2(порог устойчивости)
                fast=True
            else:                        
                fast=False

    return bases[-1], affixes

# %%
bases, affixes = build_class(affix[0])
# Out:
# Поправочный коэффициент: 5.834366282272943
# Порог редукции: 0.14073965490995827
#
# *** 1
# Основы 1-го вида: 22428 шт.
# Аффиксы  ['ы']
# Спектр остатков 1-го вида: 120394 шт.
# Прямой ход:
# Верхнее подмножество остатков текущего вида, 5 шт.
# Коррелятивная функция:  [('ыгар', 1888.1294885657364), ('га', 8.900453386931783), ('ар', 2.138241527062431), ('э', 0.20848275649659104), ('и', 0.1669302244872531)]
# Информант:  ыгар
# Мера редукции:  0.1513222832673616
# Суперпороговая редукция, ложные остатки ['ыгар']
#
# *** 1
# Основы 1-го вида: 22428 шт.
# Аффиксы  ['ы']
# Спектр остатков 1-го вида: 120394 шт.
# Прямой ход:
# Верхнее подмножество остатков текущего вида, 5 шт.
# Коррелятивная функция:  [('га', 8.900453386931783), ('ар', 2.138241527062431), ('э', 0.20848275649659104), ('и', 0.1669302244872531)]
# Информант:  га
# Мера редукции:  0.149633367323617
# Суперпороговая редукция, ложные остатки ['ыгар', 'га']
#
# *** 1
# Основы 1-го вида: 22428 шт.
# Аффиксы  ['ы']
# Спектр остатков 1-го вида: 120394 шт.
# Прямой ход:
# Верхнее подмножество остатков текущего вида, 5 шт.
# Коррелятивная функция:  [('ар', 2.138241527062431), ('э', 0.20848275649659104), ('и', 0.1669302244872531)]
# Информант:  ар
# Мера редукции:  0.16523100280408187
# Суперпороговая редукция, ложные остатки ['ыгар', 'га', 'ар']
#
# *** 1
# Основы 1-го вида: 22428 шт.
# Аффиксы  ['ы']
# Спектр остатков 1-го вида: 120394 шт.
# Прямой ход:
# Верхнее подмножество остатков текущего вида, 5 шт.
# Коррелятивная функция:  [('э', 0.20848275649659104), ('и', 0.1669302244872531)]
# Информант:  э
# Мера редукции:  0.17089383861546084
# Суперпороговая редукция, ложные остатки ['ыгар', 'га', 'ар', 'э']
#
# *** 1
# Основы 1-го вида: 22428 шт.
# Аффиксы  ['ы']
# Спектр остатков 1-го вида: 120394 шт.
# Прямой ход:
# Верхнее подмножество остатков текущего вида, 5 шт.
# Коррелятивная функция:  [('и', 0.1669302244872531)]
# Информант:  и
# Мера редукции:  0.17001499095242634
# Суперпороговая редукция, ложные остатки ['ыгар', 'га', 'ар', 'э', 'и']
#
# *** 1
# Основы 1-го вида: 22428 шт.
# Аффиксы  ['ы']
# Спектр остатков 1-го вида: 120394 шт.
# Прямой ход:
# Верхнее подмножество остатков текущего вида, 6 шт.
# Коррелятивная функция:  [('иэ', 1.926292384490568)]
# Информант:  иэ
# Мера редукции:  0.17135236783095711
# Суперпороговая редукция, ложные остатки ['ыгар', 'га', 'ар', 'э', 'и', 'иэ']
#
# *** 1
# Основы 1-го вида: 22428 шт.
# Аффиксы  ['ы']
# Спектр остатков 1-го вида: 120394 шт.
# Прямой ход:
# Верхнее подмножество остатков текущего вида, 6 шт.
# Коррелятивная функция:  [('быт', 56.403921292264094)]
# Информант:  быт
# Мера редукции:  0.16016425497284806
# Суперпороговая редукция, ложные остатки ['ыгар', 'га', 'ар', 'э', 'и', 'иэ', 'быт']
#
# *** 1
# Основы 1-го вида: 22428 шт.
# Аффиксы  ['ы']
# Спектр остатков 1-го вида: 120394 шт.
# Прямой ход:
# Верхнее подмножество остатков текущего вида, 6 шт.
# Коррелятивная функция:  [('ыта', 14.018645160085553)]
# Информант:  ыта
# Мера редукции:  0.1660945661599332
# Суперпороговая редукция, ложные остатки ['ыгар', 'га', 'ар', 'э', 'и', 'иэ', 'быт', 'ыта']
# Cуперпороговая редукция повторяется большее число раз, чем средняя длина словоформы

# %%
bases, affixes
# Out:
# (['ааган',
#   'аадаҥ',
#   'аадырыстар',
#   'аадырыһ',
#   'аай',
#   'аайтан',
#   'аайы',
#   'ааккаастанаар',
#   'ааксыйалар',
#   'ааксыйан',
#   'аакталар',
#   'аактан',
#   'аактар',
#   'аал',
#   'аалаачч',
#   'аалааччын',
#   'аалар',
#   'ааллан',
#   'ааллар',
#   'аалсыын',
#   'аалсыһы',
#   'аалы',
#   'аалыллыын',
#   'аалыын',
#   'аалыҥнаһы',
#   'аалыҥны',
#   'аамайданы',
#   'аамайдаһы',
#   'аамайды',
#   'аан',
#   'аанан',
#   'аангылыйалы',
#   'ааннааҕ',
#   'ааннар',
#   'аанньал',
#   'аанньалааҕ',
#   'аанньаллар',
#   'аанчыг',
#   'аанынааҕ',
#   'ааныскан',
#   'ааныстааҕ',
#   'ааныһ',
#   'ааппый',
#   'ааптар',
#   'ааптардар',
#   'ааратааҥҥ',
#   'аараҕ',
#   'аарг',
#   'ааркалар',
#   'ааркалы',
#   'ааркан',
#   'ааркатыҥ',
#   'аармыйалаар',
#   'аармыйалар',
#   'аармыйан',
#   'аармыйатааҕ',
#   'аартыг',
#   'аартыгынааҕ',
#   'аартыктааҕ',
#   'аартыктар',
#   'аары',
#   'аарыг',
#   'аарыгырачч',
#   'аарыгыры',
#   'аарыйалар',
#   'аарымалар',
#   'аарыман',
#   'аарыын',
#   'ааспыт',
#   'ааспыттааҕ',
#   'ааспыттааҥ',
#   'ааспыттааҥҥ',
#   'ааспыттар',
#   'ааспытты',
#   'ааспытыны',
#   'аасыһаар',
#   'аат',
#   'ааттаабытыны',
#   'ааттаар',
#   'ааттаахтар',
#   'ааттаачч',
#   'ааттааҕ',
#   'ааттааһын',
#   'ааттаммыттар',
#   'ааттанаар',
#   'ааттанаачч',
#   'ааттанааччылар',
#   'ааттанааччын',
#   'ааттаны',
#   'ааттаныын',
#   'ааттар',
#   'ааттаспытты',
#   'ааттат',
#   'ааттатаар',
#   'ааттаталы',
#   'ааттаталыыр',
#   'ааттатар',
#   'ааттатарды',
#   'ааттаты',
#   'ааттаһаачч',
#   'ааттаһарды',
#   'ааттаһы',
#   'аатты',
#   'ааттыаҕ',
#   'ааттыылларыны',
#   'ааттыыр',
#   'аатыны',
#   'аатыраар',
#   'аатыраачч',
#   'аатыралларыны',
#   'аатырбыттар',
#   'аатырдаар',
#   'аатырды',
#   'аатыры',
#   'аатырымаар',
#   'аатырыын',
#   'аахайбатахты',
#   'аахайбатты',
#   'аахайы',
#   'аахпатты',
#   'аахпыт',
#   'аахпыттар',
#   'аахпытты',
#   'аахсаар',
#   'аахсар',
#   'аахсарды',
#   'аахсы',
#   'аахсыбатты',
#   'аахсыйалаахтар',
#   'аахсыйалар',
#   'аахсыйан',
#   'аахсымаар',
#   'аахсыын',
#   'аахтан',
#   'аахтараар',
#   'аахтары',
#   'аачч',
#   'ааҕ',
#   'ааҕаар',
#   'ааҕаач',
#   'ааҕаачч',
#   'ааҕааччылар',
#   'ааҕааччын',
#   'ааҕалларыны',
#   'ааҕар',
#   'ааҕарды',
#   'ааҕы',
#   'ааҕыаҕ',
#   'ааҕыллаачч',
#   'ааҕыллараар',
#   'ааҕыллы',
#   'ааҕыллыбыт',
#   'ааҕымаар',
#   'ааҕын',
#   'ааҕыннар',
#   'ааҕыны',
#   'ааҕыныстыбалар',
#   'ааҕыныстыбан',
#   'ааҕыныын',
#   'ааҕыталы',
#   'ааҕыыг',
#   'ааҕыылар',
#   'ааҕыын',
#   'ааҕыыһ',
#   'ааҥны',
#   'ааҥныырыны',
#   'ааҥныыһ',
#   'ааҥыллы',
#   'ааһаар',
#   'ааһаачч',
#   'ааһааччылар',
#   'ааһар',
#   'ааһарды',
#   'ааһарыны',
#   'ааһы',
#   'ааһыахты',
#   'ааһыаҕ',
#   'ааһыллаачч',
#   'ааһыны',
#   'ааһыныын',
#   'ааһыталы',
#   'ааһыын',
#   'ааһыыһ',
#   'ааөҕы',
#   'аб',
#   'абааман',
#   'абаансалааһын',
#   'абаансан',
#   'абааһ',
#   'абааһылааҕ',
#   'абааһылар',
#   'абааһыларды',
#   'абааһылы',
#   'абааһын',
#   'абаб',
#   'абай',
#   'абакаров',
#   'абакаядан',
#   'абаккарбытты',
#   'абалаахтааҕ',
#   'абаламмытты',
#   'абан',
#   'абарбытты',
#   'абары',
#   'абарыын',
#   'абатыйбытты',
#   'абатыйы',
#   'абациев',
#   'абаҕан',
#   'абаҕатааҕ',
#   'аббаб',
#   'аббаһ',
#   'аббревиатуран',
#   'абдулатипов',
#   'абдулбеков',
#   'абдуллаев',
#   'абдуллан',
#   'абдулманапов',
#   'абдурагимов',
#   'абдурахман',
#   'абдусаламов',
#   'абдылдаев',
#   'абзаһ',
#   'абикенов',
#   'абитуралы',
#   'абитуран',
#   'абитуриен',
#   'абитуриеннар',
#   'абитуриенны',
#   'абкн',
#   'абонеменнар',
#   'абонен',
#   'абоненнар',
#   'абориген',
#   'аборт',
#   'абрамов',
#   'абрамован',
#   'абрамовиһ',
#   'абрамовнан',
#   'абрамовтар',
#   'абраханов',
#   'абрахимин',
#   'абрутиһ',
#   'абсолютнай',
#   'абушев',
#   'абхазеһ',
#   'абхазиян',
#   'абхазтар',
#   'абый',
#   'абыйдааҕ',
#   'абылаар',
#   'абылаппытты',
#   'абылаты',
#   'абылаҥ',
#   'абылы',
#   'абыраамаар',
#   'абыраар',
#   'абыраачч',
#   'абырал',
#   'абыранаар',
#   'абыранаачч',
#   'абыраны',
#   'абыратаар',
#   'абырахтаар',
#   'абырахтааһын',
#   'абырахтанаар',
#   'абырахты',
#   'абыраһы',
#   'абыры',
#   'абырынаар',
#   'абырыыһ',
#   'абырҕал',
#   'абытайбы',
#   'абыыры',
#   'абыычай',
#   'абыычайдар',
#   'авакумов',
#   'аваланшан',
#   'авантюр',
#   'авариялар',
#   'авариян',
#   'августин',
#   'авдеев',
#   'авелеван',
#   'аверинскай',
#   'авиабазан',
#   'авиабуомбан',
#   'авиакеросин',
#   'авиакомпаниялар',
#   'авиакомпаниян',
#   'авиалиниялар',
#   'авиамаршруттар',
#   'авиапааркан',
#   'авиапаркан',
#   'авиаперевозкан',
#   'авиаперевозчиг',
#   'авиаплощадкалар',
#   'авиаплощадкан',
#   'авиапортар',
#   'авиапредприятиен',
#   'авиаробот',
#   'авиатехниктар',
#   'авиатор',
#   'авиатордар',
#   'авиаучилищен',
#   'авиахампаанньалар',
#   'авиахампаанньан',
#   'авиахампааньалар',
#   'авиациян',
#   'авионикан',
#   'авксентьев',
#   'авокадон',
#   'австралиян',
#   'австрийскаян',
#   'австриян',
#   'австриятааҕ',
#   'автарханов',
#   'автобазан',
#   'автобустар',
#   'автовокзал',
#   'автодоилкалар',
#   'автодойкан',
#   'автодорожнай',
#   'автодорожнайдааҕ',
#   'автодромнар',
#   'автозаправкан',
#   'автококзал',
#   'автокран',
#   'автокыраан',
#   'автомагистраллар',
#   'автомасссыынан',
#   'автомассыынан',
#   'автомастарыскыайдар',
#   'автомат',
#   'автоматизациян',
#   'автоматикан',
#   'автоматтар',
#   'автоматчиг',
#   'автоматчиктар',
#   'автомеханиктар',
#   'автомобил',
#   'автомобиллар',
#   'автономиян',
#   'автооскуолалар',
#   'автопробег',
#   'автор',
#   'автордар',
#   'автореферат',
#   'авторитет',
#   'авторучкан',
#   'автослесардар',
#   'автострадан',
#   'автостраховкан',
#   'автотехникан',
#   'автотранспор',
#   'автотрассан',
#   'автоцистерналар',
#   'авшарян',
#   'аг',
#   'агалааҕ',
#   'агапудовнан',
#   'агапэн',
#   'агафиян',
#   'агафьян',
#   'агеев',
#   'агеевнан',
#   'аген',
#   'агенствон',
#   'агентстволар',
#   'агентствон',
#   'агилеран',
#   'агинскайдааҕ',
#   'агитатор',
#   'агитатордар',
#   'агитаторды',
#   'агитациялы',
#   'агитациян',
#   'агитзоналар',
#   'агнессан',
#   'агнеһ',
#   'аграрийдар',
#   'аграрнай',
#   'аграрниктар',
#   'агрегат',
#   'агрессиян',
#   'агрессор',
#   'агрогородоктар',
#   'агрозонан',
#   'агрокомплекс',
#   'агрокооперативтар',
#   'агрокуорат',
#   'агроменеджер',
#   'агрономнар',
#   'агрооскуолалар',
#   'агрооскуолан',
#   'агропааркалар',
#   'агропаркалар',
#   'агропуойаһ',
#   'агротуризм',
#   'агрофирман',
#   'агрохимикаттар',
#   'агрохолдин',
#   'агрохолдиннар',
#   'адаам',
#   'адаар',
#   'адаарычч',
#   'адаарыһы',
#   'адабашьян',
#   'адам',
#   'адамишев',
#   'адамов',
#   'адамован',
#   'адамовтар',
#   'адамс',
#   'адаптаассыйан',
#   'адаптацияланы',
#   'адаптациян',
#   'адарай',
#   'адаҕан',
#   'адаҕыйаар',
#   'адвокат',
#   'адвокаттар',
#   'адвокатуран',
#   'адесокан',
#   'аджапаридзен',
#   'адлитен',
#   'админ',
#   'администратодар',
#   'администратор',
#   'администраторды',
#   'администрациян',
#   'адмирал',
#   'адмресурсан',
#   'адон',
#   'адриамалалан',
#   'адыачч',
#   'адыаччытааҕ',
#   'адыгеян',
#   'адыгыры',
#   'адьарай',
#   'адьарайдар',
#   'адьылы',
#   'адьынат',
#   'адьынаттаахтар',
#   'адьырҕалар',
#   'адьырҕалы',
#   'адьырҕан',
#   'адьютантован',
#   'аждарл',
#   'ажибан',
#   'ажиотаһ',
#   'азалиян',
#   'азарин',
#   'азаров',
#   'азбукан',
#   'азербайджан',
#   'азербайджанеһ',
#   'азербайджаннааҕ',
#   'азербайджаннар',
#   'азербайджданны',
#   'азиат',
#   'азиаттар',
#   'азиатты',
#   'азиев',
#   'азизов',
#   'азияларды',
#   'азиялы',
#   'азиян',
#   'азиятааҕ',
#   'аидан',
#   'ай',
#   'айаал',
#   'айааллааҕ',
#   'айаан',
#   'айааннаар',
#   'айааннар',
#   'айаар',
#   'айаары',
#   'айаатаар',
#   'айааты',
#   'айаачч',
#   'айааччылар',
#   'айааһы',
#   'айакалы',
#   'айаккалы',
#   'айаккы',
#   'айалар',
#   'айалы',
#   'айан',
#   'айаннаабытты',
#   'айаннаамаар',
#   'айаннаар',
#   'айаннаачч',
#   'айаннааччылар',
#   'айаннааччын',
#   'айаннааһын',
#   'айаннар',
#   'айаннатаачч',
#   'айанны',
#   'айанныыр',
#   'айанныырды',
#   'айанныырыны',
#   'айанньыт',
#   'айанньыттар',
#   'айаныны',
#   'айар',
#   'айархаан',
#   'айахтааҕ',
#   'айахтар',
#   'айачч',
#   'айаҕ',
#   'айаҕаланы',
#   'айаҕалы',
#   'айбардаар',
#   'айбардааһын',
#   'айбарды',
#   'айбытыны',
#   'айвазян',
#   'айгылаан',
#   'айгырааһын',
#   'айгыраты',
#   'айгыры',
#   'айгысты',
#   'айдаан',
#   'айдааннар',
#   'айдаар',
#   'айдаараар',
#   'айдаарар',
#   'айдаариг',
#   'айдаарсы',
#   'айдаары',
#   'айдары',
#   'айдарыылаахтар',
#   'айдербег',
#   'айдын',
#   'айзенберг',
#   'аймаамаар',
#   'аймаар',
#   'аймаачч',
#   'аймааччылар',
#   'аймааһын',
#   'аймалаһы',
#   'аймалҕан',
#   'айманаачч',
#   'айманар',
#   'айманы',
#   'айманыллаачч',
#   'айманыын',
#   'аймахтар',
#   'аймахтаһы',
#   'аймахтаһыын',
#   'аймахты',
#   'аймахтыылар',
#   'аймаҕ',
#   'аймаҕыргы',
#   'аймаҕырҕаабытты',
#   'аймаҕырҕы',
#   'аймаөҕ',
#   'аймы',
#   'аймыыр',
#   'аймыырды',
#   'айн',
#   'айналар',
#   'айоватааҕ',
#   'айпад',
#   'айрапетян',
#   'айсбер',
#   'айсен',
#   'айсеннааҕ',
#   'айтал',
#   'айталинан',
#   'айталлар',
#   'айтан',
#   'айтикенов',
#   'айтматов',
#   'айхаар',
#   'айхал',
#   'айхаллааҕ',
#   'айхаллы',
#   'айханов',
#   'айы',
#   'айыккабы',
#   'айыкы',
#   'айылаахты',
#   'айылааҕ',
#   'айылг',
#   'айылгылаахтар',
#   'айылгылааҕ',
#   'айылгын',
#   'айыллаанан',
#   'айыллаар',
#   'айыллаачч',
#   'айыллы',
#   'айыллыаҕ',
#   'айыллыбыт',
#   'айыллыын',
#   'айылҕалы',
#   'айылҕан',
#   'айылҕөан',
#   'айымдь',
#   'айымнь',
#   'айымньылар',
#   'айымньын',
#   'айымньытыны',
#   'айысхаанан',
#   'айыылар',
#   'айыылы',
#   'айыын',
#   'айыынан',
#   'айыыһыт',
#   'айҕар',
#   'ак',
#   'акаар',
#   'акаарылар',
#   'акаарын',
#   'акаарытыйы',
#   'акаарытыҥ',
#   'акаарычааннар',
#   'академиг',
#   'академиктар',
#   'академическайды',
#   'академиялар',
#   'академиян',
#   'акаев',
#   'акаисин',
#   'акакиев',
#   'акациян',
#   'аквапаркалар',
#   'акилов',
#   'акимов',
#   'акимован',
#   'акимовнан',
#   'акин',
#   'акк',
#   'аккаастаар',
#   'аккаастаачч',
#   'аккаастаммыттар',
#   'аккаастан',
#   'аккаастанаар',
#   'аккаастанаачч',
#   'аккаастанар',
#   'аккаастаны',
#   'аккаастаныын',
#   'аккаасты',
#   'аккаастыыр',
#   'аккааһ',
#   'акккредитациян',
#   'акклиматизациян',
#   'аккортар',
#   'аккредитациян',
#   'аккредитициян',
#   'аккумулятор',
#   'аккумулятордар',
#   'аккырыыккалар',
#   'аккырыыккан',
#   'аклиматизациян',
#   'акмолан',
#   'акробат',
#   'акробатикан',
#   'акробаттар',
#   'акробатты',
#   'аксакаллар',
#   'аксеньян',
#   'аксессуар',
#   'аксессуардар',
#   'акт',
#   'акталар',
#   'актан',
#   'актар',
#   'актердар',
#   'актив',
#   'активистар',
#   'активисткалар',
#   'активиһ',
#   'активтар',
#   'актобиятааҕ',
#   'актыбыыстар',
#   'актыыб',
#   'актыыбынаһ',
#   'актыыптар',
#   'актюбинскайдааҕ',
#   'акулалар',
#   'акулинан',
#   'акулован',
#   'акунин',
#   'акустикан',
#   'акушердар',
#   'акционердар',
#   'акциялааһын',
#   'акциялар',
#   'акциян',
#   'акциһ',
#   'акыйаан',
#   'акыйааннааҕ',
#   'акыйааннар',
#   'акылаат',
#   'акылааттар',
#   'акырабаатыкан',
#   'акыым',
#   'ал',
#   'алаадычч',
#   'алаадь',
#   'алаадьылар',
#   'алаадьылы',
#   'алаадьын',
#   'алааппыйан',
#   'алаарааҥҥ',
#   'алаарычч',
#   'алаастар',
#   'алаастаһы',
#   'алаастаһыын',
#   'алаастыҥ',
#   'алааҕ',
#   'алааһ',
#   'алабаман',
#   'алакы',
#   'алампалы',
#   'алампан',
#   'алар',
#   'алахчын',
#   'алаһалар',
#   'алаһыай',
#   'алаһыайдар',
#   'албакаат',
#   'албакааттар',
#   'албакаатты',
#   'албанны',
#   'албарст',
#   'албасл',
#   'албасс',
#   'албаст',
#   'албастаар',
#   'албастаахтар',
#   'албастааҕ',
#   'албастааһын',
#   'албастар',
#   'албастаһы',
#   'албасты',
#   'албастын',
#   'албаһ',
#   'албаһыры',
#   'албн',
#   'албын',
#   'албыннаабыттар',
#   'албыннаар',
#   'албыннаачч',
#   'албыннааччылар',
#   'албыннааһын',
#   'албыннаны',
#   'албыннаныын',
#   'албыннатаачч',
#   'албыннаталы',
#   'албыннаты',
#   'албыннаһаар',
#   'албыннаһаачч',
#   'албыннаһар',
#   'албыннаһарды',
#   'албыннаһы',
#   'албыннаһыын',
#   'албынны',
#   'албынныыр',
#   'алгебран',
#   'алгоритм',
#   'алгы',
#   'алгыстааһын',
#   'алгыстаны',
#   'алгыстар',
#   'алгысты',
#   'алгысчыт',
#   'алгысчыттар',
#   'алгыһ',
#   'алдан',
#   'алданнааҕ',
#   'алданнар',
#   'алдатов',
#   'алдьаммыт',
#   'алдьанаар',
#   'алдьаны',
#   'алдьаныылар',
#   'алдьаныын',
#   'алдьаппыт',
#   'алдьархай',
#   'алдьархайдар',
#   'алдьатаар',
#   'алдьатаачч',
#   'алдьатааччылар',
#   'алдьатар',
#   'алдьаты',
#   'алдьатымаар',
#   'алдьатыылааҕ',
#   'алдьатыылар',
#   'алдьатыын',
#   'алдьатыыһ',
#   'алебастр',
#   'алевтинан',
#   'александр',
#   'александран',
#   'александров',
#   'александрован',
#   'александровиһ',
#   'александровнан',
#   'алексеев',
#   'алексееван',
#   'алексеевичтааҕ',
#   'алексеевиһ',
#   'алексеевнан',
#   'алексеевскайдааҕ',
#   'алексеевтааҕ',
#   'алексеевтар',
#   'алексеенкон',
#   'алексей',
#   'алексий',
#   'алексийды',
#   'алексиһ',
#   'ален',
#   'аленан',
#   'алесян',
#   'алеуттар',
#   'алехинан',
#   'алешан',
#   'алешин',
#   'алешинан',
#   'алиасгар',
#   'алибегашвилин',
#   'алиг',
#   'алиев',
#   'алиевиһ',
#   'аликс',
#   'алимбаев',
#   'алимен',
#   'алимент',
#   'алин',
#   'алинан',
#   'алинскайдааҕ',
#   'алисан',
#   'алиһ',
#   'алкатестер',
#   'алкатестердар',
#   'алкогол',
#   'алкоголизациян',
#   'алкоголизм',
#   'алл',
#   'аллаахтар',
#   'аллааҕ',
#   'аллааҕыскай',
#   'аллайталы',
#   'аллайх',
#   'аллайы',
#   'аллайыахалар',
#   'аллайыахан',
#   'аллайыахатааҕ',
#   'аллайыын',
#   'аллан',
#   'аллар',
#   'аллараан',
#   'аллараар',
#   'аллараачч',
#   'алларааҥ',
#   'алларааҥҥ',
#   'алларааҥҥылар',
#   'алларан',
#   'алларар',
#   'алларастаһы',
#   'алларасты',
#   'аллары',
#   'алларыйы',
#   'алларыты',
#   'аллахинован',
#   'аллачч',
#   'аллегориян',
#   'аллергиялы',
#   'аллеян',
#   'аллитерациян',
#   'аллыйк',
#   'алмаастар',
#   'алмаасты',
#   'алмаасчыт',
#   'алмаасчыттар',
#   'алмааьыны',
#   'алмааһ',
#   'алмааһыны',
#   'алмаз',
#   'алмазэргиэнбаан',
#   'алмаст',
#   'алмат',
#   'алматын',
#   'алоэн',
#   'алоян',
#   'алпаабыт',
#   'алрос',
#   'алросан',
#   'алсырд',
#   'алт',
#   'алтаай',
#   'алтаайдааҕ',
#   'алтаайдар',
#   'алтаайды',
#   'алтай',
#   'алтайдааҕ',
#   'алтайдар',
#   'алтайды',
#   'алтайтар',
#   'алталы',
#   'алталыын',
#   'алтан',
#   'алтаннааҕ',
#   'алтанны',
#   'алторкин',
#   'алтухован',
#   'алтынн',
#   'алтыннь',
#   'алтынньын',
#   'алтынньытааҕ',
#   'алтынь',
#   'алтыһ',
#   'алтыһар',
#   'алтыһы',
#   'алтыһыннар',
#   'алтыһыннарар',
#   'алтыһыннары',
#   'алтыһыын',
#   'алушкин',
#   'алфавит',
#   'алфавиттар',
#   'алшимбаев',
#   'алы',
#   'алыб',
#   'алыбыны',
#   'алымбаев',
#   'алыптааҕ',
#   'алыын',
#   'алыытааҕ',
#   'алыҥнааҕ',
#   'алыҥҥ',
#   'алыһ',
#   'алыһар',
#   'алыһардааҕ',
#   'алыһардар',
#   'альб',
#   'альбан',
#   'альберт',
#   'альбинан',
#   'альбомнар',
#   'альварадон',
#   'альманаҕ',
#   'альп',
#   'альперовиһ',
#   'альпинистар',
#   'альянс',
#   'алялааҕ',
#   'алян',
#   'аляскан',
#   'аляскатааҕ',
#   'алёшан',
#   'алҕаабытыны',
#   'алҕаар',
#   'алҕан',
#   'алҕастар',
#   'алҕаһ',
#   'алҕаһаабыт',
#   'алҕаһаачч',
#   'алҕаһы',
#   'алҕы',
#   'алҕысчыт',
#   'амазонкан',
#   'амакинкатааҕ',
#   'амакинскайдааҕ',
#   'амалар',
#   'аманааттар',
#   'аманатов',
#   'аманатован',
#   'амангельд',
#   'амбициян',
#   'амбросьев',
#   'амбулаториялар',
#   'амбулаториян',
#   'амгайаанан',
#   'америкалы',
#   'американ',
#   'американецтар',
#   'американеһ',
#   'американны',
#   'америкатааҕ',
#   'аминокислотан',
#   'амирханлин',
#   'аммалар',
#   'амман',
#   'амматааҕ',
#   'аммиаг',
#   'аммосов',
#   'аммосован',
#   'аммосовтааҕ',
#   'амнистиялааһын',
#   'амнистиян',
#   'амнь',
#   'амньыыстыйан',
#   'амозонит',
#   'амортизатор',
#   'амосов',
#   'ампаалыктаны',
#   ...],
#  ['ы'])

# %%
for j in range(0, len(informants)):
    print(extend_left(extend_right([i for i in informants[j]])
    for aff in informants:
----> 3         affix=[extend_left(extend_right(aff), trie, 7)]
# Out:
#   File "<ipython-input-24-03e434484a26>", line 3
#     for aff in informants:
#                          ^
# SyntaxError: invalid syntax

# %%
all(e for e in n if all(n.startswith('а'))
# Out:
#   File "<ipython-input-45-5492a9c97f18>", line 1
#     all(e for e in n if all(n.startswith('а'))
#                                               ^
# SyntaxError: unexpected EOF while parsing

# %%
t=[i for i in informants]
t[0]
# Out:
# ('н', -1, 3.15594279017803)

# %%
affix[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-17a0499e3868> in <module>()
# ----> 1 affix[0]
#
# NameError: name 'affix' is not defined
